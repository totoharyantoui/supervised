# %%
# Regression Example With Boston Dataset: Standardized and Larger
from pandas import read_csv
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

# load dataset
#dataframe = read_csv("housing.csv",delim_whitespace=True, header=None)
dataframe = read_csv("weather_coma_delimiter.csv",delim_whitespace=True, header=None)

dataset = dataframe.values
print(dataset)
# split into input (X) and output (Y) variables
X = dataset[:,1:16]
print(X)
Y = dataset[:,16]
print(Y)
# define the model
def larger_model():
	# create model
	model = Sequential()
	model.add(Dense(13, input_dim=15, kernel_initializer='normal', activation='relu'))
	model.add(Dense(6, kernel_initializer='normal', activation='relu'))
	model.add(Dense(1, kernel_initializer='normal'))
	# Compile model
	model.compile(loss='mean_squared_error', optimizer='adam')
	return model
# evaluate model with standardized dataset
estimators = []
estimators.append(('standardize', StandardScaler()))
estimators.append(('mlp', KerasRegressor(build_fn=larger_model, epochs=50, batch_size=5, verbose=1)))
pipeline = Pipeline(estimators)
kfold = KFold(n_splits=10)
results = cross_val_score(pipeline, X, Y, cv=kfold)
print("Larger: %.2f (%.2f) MSE" % (results.mean(), results.std()))
# Out:
# [[0.000e+00 7.400e+01 6.000e+01 ... 4.000e+00 3.100e+01 4.600e-01]
#  [1.000e+00 5.600e+01 4.800e+01 ... 6.000e+00 2.500e+01 0.000e+00]
#  [2.000e+00 5.800e+01 4.500e+01 ... 3.000e+00 1.200e+01 0.000e+00]
#  ...
#  [1.316e+03 1.070e+02 9.200e+01 ... 4.000e+00 1.700e+01 0.000e+00]
#  [1.317e+03 1.060e+02 9.300e+01 ... 4.000e+00 2.000e+01 0.000e+00]
#  [1.318e+03 9.900e+01 8.800e+01 ... 4.000e+00 2.000e+01 0.000e+00]]
# [[ 74.  60.  45. ...   7.   2.  20.]
#  [ 56.  48.  39. ...  10.   5.  16.]
#  [ 58.  45.  32. ...  10.  10.   8.]
#  ...
#  [107.  92.  77. ...  10.  10.  12.]
#  [106.  93.  79. ...  10.  10.  13.]
#  [ 99.  88.  77. ...  10.  10.  12.]]
# [31. 25. 12. ... 17. 20. 20.]
# Epoch 1/50
# Epoch 1/50
# /home/toto/project_1/project_1/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:614: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/sklearn/pipeline.py", line 346, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/keras/wrappers/scikit_learn.py", line 163, in fit
#     history = self.model.fit(x, y, **fit_args)
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/keras/engine/training.py", line 1158, in fit
#     tmp_logs = self.train_function(iterator)
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/tensorflow/python/eager/def_function.py", line 889, in __call__
#     result = self._call(*args, **kwds)
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/tensorflow/python/eager/def_function.py", line 933, in _call
#     self._initialize(args, kwds, add_initializers_to=initializers)
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/tensorflow/python/eager/def_function.py", line 764, in _initialize
#     *args, **kwds))
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/tensorflow/python/eager/function.py", line 3050, in _get_concrete_function_internal_garbage_collected
#     graph_function, _ = self._maybe_define_function(args, kwargs)
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/tensorflow/python/eager/function.py", line 3444, in _maybe_define_function
#     graph_function = self._create_graph_function(args, kwargs)
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/tensorflow/python/eager/function.py", line 3289, in _create_graph_function
#     capture_by_value=self._capture_by_value),
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/tensorflow/python/framework/func_graph.py", line 999, in func_graph_from_py_func
#     func_outputs = python_func(*func_args, **func_kwargs)
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/tensorflow/python/eager/def_function.py", line 672, in wrapped_fn
#     out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/tensorflow/python/framework/func_graph.py", line 986, in wrapper
#     raise e.ag_error_metadata.to_exception(e)
# ValueError: in user code:
#
#     /home/toto/project_1/project_1/lib/python3.6/site-packages/keras/engine/training.py:830 train_function  *
#         return step_function(self, iterator)
#     /home/toto/project_1/project_1/lib/python3.6/site-packages/keras/engine/training.py:813 run_step  *
#         outputs = model.train_step(data)
#     /home/toto/project_1/project_1/lib/python3.6/site-packages/keras/engine/training.py:770 train_step  *
#         y_pred = self(x, training=True)
#     /home/toto/project_1/project_1/lib/python3.6/site-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /home/toto/project_1/project_1/lib/python3.6/site-packages/keras/engine/input_spec.py:248 assert_input_compatibility  *
#         raise ValueError(
#
#     ValueError: Input 0 of layer sequential_74 is incompatible with the layer: expected axis -1 of input shape to have value 15 but received input with shape (None, 14)
#
#
#   FitFailedWarning)
# /home/toto/project_1/project_1/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:614: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/sklearn/pipeline.py", line 346, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/keras/wrappers/scikit_learn.py", line 163, in fit
#     history = self.model.fit(x, y, **fit_args)
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/keras/engine/training.py", line 1158, in fit
#     tmp_logs = self.train_function(iterator)
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/tensorflow/python/eager/def_function.py", line 889, in __call__
#     result = self._call(*args, **kwds)
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/tensorflow/python/eager/def_function.py", line 933, in _call
#     self._initialize(args, kwds, add_initializers_to=initializers)
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/tensorflow/python/eager/def_function.py", line 764, in _initialize
#     *args, **kwds))
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/tensorflow/python/eager/function.py", line 3050, in _get_concrete_function_internal_garbage_collected
#     graph_function, _ = self._maybe_define_function(args, kwargs)
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/tensorflow/python/eager/function.py", line 3444, in _maybe_define_function
#     graph_function = self._create_graph_function(args, kwargs)
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/tensorflow/python/eager/function.py", line 3289, in _create_graph_function
#     capture_by_value=self._capture_by_value),
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/tensorflow/python/framework/func_graph.py", line 999, in func_graph_from_py_func
#     func_outputs = python_func(*func_args, **func_kwargs)
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/tensorflow/python/eager/def_function.py", line 672, in wrapped_fn
#     out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/tensorflow/python/framework/func_graph.py", line 986, in wrapper
#     raise e.ag_error_metadata.to_exception(e)
# ValueError: in user code:
#
#     /home/toto/project_1/project_1/lib/python3.6/site-packages/keras/engine/training.py:830 train_function  *
#         return step_function(self, iterator)
#     /home/toto/project_1/project_1/lib/python3.6/site-packages/keras/engine/training.py:813 run_step  *
#         outputs = model.train_step(data)
#     /home/toto/project_1/project_1/lib/python3.6/site-packages/keras/engine/training.py:770 train_step  *
#         y_pred = self(x, training=True)
#     /home/toto/project_1/project_1/lib/python3.6/site-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /home/toto/project_1/project_1/lib/python3.6/site-packages/keras/engine/input_spec.py:248 assert_input_compatibility  *
#         raise ValueError(
#
#     ValueError: Input 0 of layer sequential_75 is incompatible with the layer: expected axis -1 of input shape to have value 15 but received input with shape (None, 14)
#
#
#   FitFailedWarning)
# /home/toto/project_1/project_1/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:614: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/sklearn/pipeline.py", line 346, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/keras/wrappers/scikit_learn.py", line 163, in fit
#     history = self.model.fit(x, y, **fit_args)
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/keras/engine/training.py", line 1158, in fit
#     tmp_logs = self.train_function(iterator)
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/tensorflow/python/eager/def_function.py", line 889, in __call__
#     result = self._call(*args, **kwds)
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/tensorflow/python/eager/def_function.py", line 933, in _call
#     self._initialize(args, kwds, add_initializers_to=initializers)
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/tensorflow/python/eager/def_function.py", line 764, in _initialize
#     *args, **kwds))
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/tensorflow/python/eager/function.py", line 3050, in _get_concrete_function_internal_garbage_collected
#     graph_function, _ = self._maybe_define_function(args, kwargs)
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/tensorflow/python/eager/function.py", line 3444, in _maybe_define_function
#     graph_function = self._create_graph_function(args, kwargs)
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/tensorflow/python/eager/function.py", line 3289, in _create_graph_function
#     capture_by_value=self._capture_by_value),
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/tensorflow/python/framework/func_graph.py", line 999, in func_graph_from_py_func
#     func_outputs = python_func(*func_args, **func_kwargs)
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/tensorflow/python/eager/def_function.py", line 672, in wrapped_fn
#     out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/tensorflow/python/framework/func_graph.py", line 986, in wrapper
#     raise e.ag_error_metadata.to_exception(e)
# ValueError: in user code:
#
#     /home/toto/project_1/project_1/lib/python3.6/site-packages/keras/engine/training.py:830 train_function  *
#         return step_function(self, iterator)
#     /home/toto/project_1/project_1/lib/python3.6/site-packages/keras/engine/training.py:813 run_step  *
#         outputs = model.train_step(data)
#     /home/toto/project_1/project_1/lib/python3.6/site-packages/keras/engine/training.py:770 train_step  *
#         y_pred = self(x, training=True)
#     /home/toto/project_1/project_1/lib/python3.6/site-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /home/toto/project_1/project_1/lib/python3.6/site-packages/keras/engine/input_spec.py:248 assert_input_compatibility  *
#         raise ValueError(
#
#     ValueError: Input 0 of layer sequential_76 is incompatible with the layer: expected axis -1 of input shape to have value 15 but received input with shape (None, 14)
#
#
#   FitFailedWarning)
# Epoch 1/50
# Epoch 1/50
# Epoch 1/50
# /home/toto/project_1/project_1/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:614: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/sklearn/pipeline.py", line 346, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/keras/wrappers/scikit_learn.py", line 163, in fit
#     history = self.model.fit(x, y, **fit_args)
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/keras/engine/training.py", line 1158, in fit
#     tmp_logs = self.train_function(iterator)
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/tensorflow/python/eager/def_function.py", line 889, in __call__
#     result = self._call(*args, **kwds)
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/tensorflow/python/eager/def_function.py", line 933, in _call
#     self._initialize(args, kwds, add_initializers_to=initializers)
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/tensorflow/python/eager/def_function.py", line 764, in _initialize
#     *args, **kwds))
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/tensorflow/python/eager/function.py", line 3050, in _get_concrete_function_internal_garbage_collected
#     graph_function, _ = self._maybe_define_function(args, kwargs)
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/tensorflow/python/eager/function.py", line 3444, in _maybe_define_function
#     graph_function = self._create_graph_function(args, kwargs)
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/tensorflow/python/eager/function.py", line 3289, in _create_graph_function
#     capture_by_value=self._capture_by_value),
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/tensorflow/python/framework/func_graph.py", line 999, in func_graph_from_py_func
#     func_outputs = python_func(*func_args, **func_kwargs)
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/tensorflow/python/eager/def_function.py", line 672, in wrapped_fn
#     out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/tensorflow/python/framework/func_graph.py", line 986, in wrapper
#     raise e.ag_error_metadata.to_exception(e)
# ValueError: in user code:
#
#     /home/toto/project_1/project_1/lib/python3.6/site-packages/keras/engine/training.py:830 train_function  *
#         return step_function(self, iterator)
#     /home/toto/project_1/project_1/lib/python3.6/site-packages/keras/engine/training.py:813 run_step  *
#         outputs = model.train_step(data)
#     /home/toto/project_1/project_1/lib/python3.6/site-packages/keras/engine/training.py:770 train_step  *
#         y_pred = self(x, training=True)
#     /home/toto/project_1/project_1/lib/python3.6/site-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /home/toto/project_1/project_1/lib/python3.6/site-packages/keras/engine/input_spec.py:248 assert_input_compatibility  *
#         raise ValueError(
#
#     ValueError: Input 0 of layer sequential_77 is incompatible with the layer: expected axis -1 of input shape to have value 15 but received input with shape (None, 14)
#
#
#   FitFailedWarning)
# /home/toto/project_1/project_1/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:614: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/sklearn/pipeline.py", line 346, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/keras/wrappers/scikit_learn.py", line 163, in fit
#     history = self.model.fit(x, y, **fit_args)
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/keras/engine/training.py", line 1158, in fit
#     tmp_logs = self.train_function(iterator)
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/tensorflow/python/eager/def_function.py", line 889, in __call__
#     result = self._call(*args, **kwds)
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/tensorflow/python/eager/def_function.py", line 933, in _call
#     self._initialize(args, kwds, add_initializers_to=initializers)
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/tensorflow/python/eager/def_function.py", line 764, in _initialize
#     *args, **kwds))
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/tensorflow/python/eager/function.py", line 3050, in _get_concrete_function_internal_garbage_collected
#     graph_function, _ = self._maybe_define_function(args, kwargs)
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/tensorflow/python/eager/function.py", line 3444, in _maybe_define_function
#     graph_function = self._create_graph_function(args, kwargs)
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/tensorflow/python/eager/function.py", line 3289, in _create_graph_function
#     capture_by_value=self._capture_by_value),
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/tensorflow/python/framework/func_graph.py", line 999, in func_graph_from_py_func
#     func_outputs = python_func(*func_args, **func_kwargs)
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/tensorflow/python/eager/def_function.py", line 672, in wrapped_fn
#     out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/tensorflow/python/framework/func_graph.py", line 986, in wrapper
#     raise e.ag_error_metadata.to_exception(e)
# ValueError: in user code:
#
#     /home/toto/project_1/project_1/lib/python3.6/site-packages/keras/engine/training.py:830 train_function  *
#         return step_function(self, iterator)
#     /home/toto/project_1/project_1/lib/python3.6/site-packages/keras/engine/training.py:813 run_step  *
#         outputs = model.train_step(data)
#     /home/toto/project_1/project_1/lib/python3.6/site-packages/keras/engine/training.py:770 train_step  *
#         y_pred = self(x, training=True)
#     /home/toto/project_1/project_1/lib/python3.6/site-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /home/toto/project_1/project_1/lib/python3.6/site-packages/keras/engine/input_spec.py:248 assert_input_compatibility  *
#         raise ValueError(
#
#     ValueError: Input 0 of layer sequential_78 is incompatible with the layer: expected axis -1 of input shape to have value 15 but received input with shape (None, 14)
#
#
#   FitFailedWarning)
# /home/toto/project_1/project_1/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:614: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/sklearn/pipeline.py", line 346, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/keras/wrappers/scikit_learn.py", line 163, in fit
#     history = self.model.fit(x, y, **fit_args)
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/keras/engine/training.py", line 1158, in fit
#     tmp_logs = self.train_function(iterator)
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/tensorflow/python/eager/def_function.py", line 889, in __call__
#     result = self._call(*args, **kwds)
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/tensorflow/python/eager/def_function.py", line 933, in _call
#     self._initialize(args, kwds, add_initializers_to=initializers)
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/tensorflow/python/eager/def_function.py", line 764, in _initialize
#     *args, **kwds))
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/tensorflow/python/eager/function.py", line 3050, in _get_concrete_function_internal_garbage_collected
#     graph_function, _ = self._maybe_define_function(args, kwargs)
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/tensorflow/python/eager/function.py", line 3444, in _maybe_define_function
#     graph_function = self._create_graph_function(args, kwargs)
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/tensorflow/python/eager/function.py", line 3289, in _create_graph_function
#     capture_by_value=self._capture_by_value),
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/tensorflow/python/framework/func_graph.py", line 999, in func_graph_from_py_func
#     func_outputs = python_func(*func_args, **func_kwargs)
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/tensorflow/python/eager/def_function.py", line 672, in wrapped_fn
#     out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/tensorflow/python/framework/func_graph.py", line 986, in wrapper
#     raise e.ag_error_metadata.to_exception(e)
# ValueError: in user code:
#
#     /home/toto/project_1/project_1/lib/python3.6/site-packages/keras/engine/training.py:830 train_function  *
#         return step_function(self, iterator)
#     /home/toto/project_1/project_1/lib/python3.6/site-packages/keras/engine/training.py:813 run_step  *
#         outputs = model.train_step(data)
#     /home/toto/project_1/project_1/lib/python3.6/site-packages/keras/engine/training.py:770 train_step  *
#         y_pred = self(x, training=True)
#     /home/toto/project_1/project_1/lib/python3.6/site-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /home/toto/project_1/project_1/lib/python3.6/site-packages/keras/engine/input_spec.py:248 assert_input_compatibility  *
#         raise ValueError(
#
#     ValueError: Input 0 of layer sequential_79 is incompatible with the layer: expected axis -1 of input shape to have value 15 but received input with shape (None, 14)
#
#
#   FitFailedWarning)
# Epoch 1/50
# Epoch 1/50
# Epoch 1/50
# Epoch 1/50
# Epoch 1/50
# Larger: nan (nan) MSE
# /home/toto/project_1/project_1/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:614: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/sklearn/pipeline.py", line 346, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/keras/wrappers/scikit_learn.py", line 163, in fit
#     history = self.model.fit(x, y, **fit_args)
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/keras/engine/training.py", line 1158, in fit
#     tmp_logs = self.train_function(iterator)
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/tensorflow/python/eager/def_function.py", line 889, in __call__
#     result = self._call(*args, **kwds)
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/tensorflow/python/eager/def_function.py", line 933, in _call
#     self._initialize(args, kwds, add_initializers_to=initializers)
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/tensorflow/python/eager/def_function.py", line 764, in _initialize
#     *args, **kwds))
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/tensorflow/python/eager/function.py", line 3050, in _get_concrete_function_internal_garbage_collected
#     graph_function, _ = self._maybe_define_function(args, kwargs)
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/tensorflow/python/eager/function.py", line 3444, in _maybe_define_function
#     graph_function = self._create_graph_function(args, kwargs)
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/tensorflow/python/eager/function.py", line 3289, in _create_graph_function
#     capture_by_value=self._capture_by_value),
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/tensorflow/python/framework/func_graph.py", line 999, in func_graph_from_py_func
#     func_outputs = python_func(*func_args, **func_kwargs)
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/tensorflow/python/eager/def_function.py", line 672, in wrapped_fn
#     out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/tensorflow/python/framework/func_graph.py", line 986, in wrapper
#     raise e.ag_error_metadata.to_exception(e)
# ValueError: in user code:
#
#     /home/toto/project_1/project_1/lib/python3.6/site-packages/keras/engine/training.py:830 train_function  *
#         return step_function(self, iterator)
#     /home/toto/project_1/project_1/lib/python3.6/site-packages/keras/engine/training.py:813 run_step  *
#         outputs = model.train_step(data)
#     /home/toto/project_1/project_1/lib/python3.6/site-packages/keras/engine/training.py:770 train_step  *
#         y_pred = self(x, training=True)
#     /home/toto/project_1/project_1/lib/python3.6/site-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /home/toto/project_1/project_1/lib/python3.6/site-packages/keras/engine/input_spec.py:248 assert_input_compatibility  *
#         raise ValueError(
#
#     ValueError: Input 0 of layer sequential_80 is incompatible with the layer: expected axis -1 of input shape to have value 15 but received input with shape (None, 14)
#
#
#   FitFailedWarning)
# /home/toto/project_1/project_1/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:614: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/sklearn/pipeline.py", line 346, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/keras/wrappers/scikit_learn.py", line 163, in fit
#     history = self.model.fit(x, y, **fit_args)
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/keras/engine/training.py", line 1158, in fit
#     tmp_logs = self.train_function(iterator)
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/tensorflow/python/eager/def_function.py", line 889, in __call__
#     result = self._call(*args, **kwds)
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/tensorflow/python/eager/def_function.py", line 933, in _call
#     self._initialize(args, kwds, add_initializers_to=initializers)
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/tensorflow/python/eager/def_function.py", line 764, in _initialize
#     *args, **kwds))
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/tensorflow/python/eager/function.py", line 3050, in _get_concrete_function_internal_garbage_collected
#     graph_function, _ = self._maybe_define_function(args, kwargs)
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/tensorflow/python/eager/function.py", line 3444, in _maybe_define_function
#     graph_function = self._create_graph_function(args, kwargs)
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/tensorflow/python/eager/function.py", line 3289, in _create_graph_function
#     capture_by_value=self._capture_by_value),
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/tensorflow/python/framework/func_graph.py", line 999, in func_graph_from_py_func
#     func_outputs = python_func(*func_args, **func_kwargs)
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/tensorflow/python/eager/def_function.py", line 672, in wrapped_fn
#     out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/tensorflow/python/framework/func_graph.py", line 986, in wrapper
#     raise e.ag_error_metadata.to_exception(e)
# ValueError: in user code:
#
#     /home/toto/project_1/project_1/lib/python3.6/site-packages/keras/engine/training.py:830 train_function  *
#         return step_function(self, iterator)
#     /home/toto/project_1/project_1/lib/python3.6/site-packages/keras/engine/training.py:813 run_step  *
#         outputs = model.train_step(data)
#     /home/toto/project_1/project_1/lib/python3.6/site-packages/keras/engine/training.py:770 train_step  *
#         y_pred = self(x, training=True)
#     /home/toto/project_1/project_1/lib/python3.6/site-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /home/toto/project_1/project_1/lib/python3.6/site-packages/keras/engine/input_spec.py:248 assert_input_compatibility  *
#         raise ValueError(
#
#     ValueError: Input 0 of layer sequential_81 is incompatible with the layer: expected axis -1 of input shape to have value 15 but received input with shape (None, 14)
#
#
#   FitFailedWarning)
# /home/toto/project_1/project_1/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:614: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/sklearn/pipeline.py", line 346, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/keras/wrappers/scikit_learn.py", line 163, in fit
#     history = self.model.fit(x, y, **fit_args)
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/keras/engine/training.py", line 1158, in fit
#     tmp_logs = self.train_function(iterator)
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/tensorflow/python/eager/def_function.py", line 889, in __call__
#     result = self._call(*args, **kwds)
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/tensorflow/python/eager/def_function.py", line 933, in _call
#     self._initialize(args, kwds, add_initializers_to=initializers)
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/tensorflow/python/eager/def_function.py", line 764, in _initialize
#     *args, **kwds))
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/tensorflow/python/eager/function.py", line 3050, in _get_concrete_function_internal_garbage_collected
#     graph_function, _ = self._maybe_define_function(args, kwargs)
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/tensorflow/python/eager/function.py", line 3444, in _maybe_define_function
#     graph_function = self._create_graph_function(args, kwargs)
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/tensorflow/python/eager/function.py", line 3289, in _create_graph_function
#     capture_by_value=self._capture_by_value),
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/tensorflow/python/framework/func_graph.py", line 999, in func_graph_from_py_func
#     func_outputs = python_func(*func_args, **func_kwargs)
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/tensorflow/python/eager/def_function.py", line 672, in wrapped_fn
#     out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/tensorflow/python/framework/func_graph.py", line 986, in wrapper
#     raise e.ag_error_metadata.to_exception(e)
# ValueError: in user code:
#
#     /home/toto/project_1/project_1/lib/python3.6/site-packages/keras/engine/training.py:830 train_function  *
#         return step_function(self, iterator)
#     /home/toto/project_1/project_1/lib/python3.6/site-packages/keras/engine/training.py:813 run_step  *
#         outputs = model.train_step(data)
#     /home/toto/project_1/project_1/lib/python3.6/site-packages/keras/engine/training.py:770 train_step  *
#         y_pred = self(x, training=True)
#     /home/toto/project_1/project_1/lib/python3.6/site-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /home/toto/project_1/project_1/lib/python3.6/site-packages/keras/engine/input_spec.py:248 assert_input_compatibility  *
#         raise ValueError(
#
#     ValueError: Input 0 of layer sequential_82 is incompatible with the layer: expected axis -1 of input shape to have value 15 but received input with shape (None, 14)
#
#
#   FitFailedWarning)
# /home/toto/project_1/project_1/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:614: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/sklearn/pipeline.py", line 346, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/keras/wrappers/scikit_learn.py", line 163, in fit
#     history = self.model.fit(x, y, **fit_args)
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/keras/engine/training.py", line 1158, in fit
#     tmp_logs = self.train_function(iterator)
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/tensorflow/python/eager/def_function.py", line 889, in __call__
#     result = self._call(*args, **kwds)
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/tensorflow/python/eager/def_function.py", line 933, in _call
#     self._initialize(args, kwds, add_initializers_to=initializers)
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/tensorflow/python/eager/def_function.py", line 764, in _initialize
#     *args, **kwds))
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/tensorflow/python/eager/function.py", line 3050, in _get_concrete_function_internal_garbage_collected
#     graph_function, _ = self._maybe_define_function(args, kwargs)
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/tensorflow/python/eager/function.py", line 3444, in _maybe_define_function
#     graph_function = self._create_graph_function(args, kwargs)
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/tensorflow/python/eager/function.py", line 3289, in _create_graph_function
#     capture_by_value=self._capture_by_value),
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/tensorflow/python/framework/func_graph.py", line 999, in func_graph_from_py_func
#     func_outputs = python_func(*func_args, **func_kwargs)
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/tensorflow/python/eager/def_function.py", line 672, in wrapped_fn
#     out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#   File "/home/toto/project_1/project_1/lib/python3.6/site-packages/tensorflow/python/framework/func_graph.py", line 986, in wrapper
#     raise e.ag_error_metadata.to_exception(e)
# ValueError: in user code:
#
#     /home/toto/project_1/project_1/lib/python3.6/site-packages/keras/engine/training.py:830 train_function  *
#         return step_function(self, iterator)
#     /home/toto/project_1/project_1/lib/python3.6/site-packages/keras/engine/training.py:813 run_step  *
#         outputs = model.train_step(data)
#     /home/toto/project_1/project_1/lib/python3.6/site-packages/keras/engine/training.py:770 train_step  *
#         y_pred = self(x, training=True)
#     /home/toto/project_1/project_1/lib/python3.6/site-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /home/toto/project_1/project_1/lib/python3.6/site-packages/keras/engine/input_spec.py:248 assert_input_compatibility  *
#         raise ValueError(
#
#     ValueError: Input 0 of layer sequential_83 is incompatible with the layer: expected axis -1 of input shape to have value 15 but received input with shape (None, 14)
#
#
#   FitFailedWarning)

# %%
# !pip install tensorflow
# Out:
# Collecting tensorflow
#   Downloading tensorflow-2.5.0-cp36-cp36m-manylinux2010_x86_64.whl (454.3 MB)
#      |████████████████████████████████| 454.3 MB 7.4 kB/s eta 0:00:01     |████████████████▊               | 237.9 MB 3.4 MB/s eta 0:01:05
# Collecting grpcio~=1.34.0
#   Downloading grpcio-1.34.1-cp36-cp36m-manylinux2014_x86_64.whl (4.0 MB)
#      |████████████████████████████████| 4.0 MB 4.5 MB/s eta 0:00:01
# Collecting termcolor~=1.1.0
#   Downloading termcolor-1.1.0.tar.gz (3.9 kB)
# Collecting google-pasta~=0.2
#   Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
#      |████████████████████████████████| 57 kB 1.3 MB/s eta 0:00:01
# Requirement already satisfied: wheel~=0.35 in ./project_1/lib/python3.6/site-packages (from tensorflow) (0.36.2)
# Collecting flatbuffers~=1.12.0
#   Downloading flatbuffers-1.12-py2.py3-none-any.whl (15 kB)
# Collecting wrapt~=1.12.1
#   Downloading wrapt-1.12.1.tar.gz (27 kB)
# Requirement already satisfied: h5py~=3.1.0 in ./project_1/lib/python3.6/site-packages (from tensorflow) (3.1.0)
# Collecting absl-py~=0.10
#   Downloading absl_py-0.13.0-py3-none-any.whl (132 kB)
#      |████████████████████████████████| 132 kB 4.3 MB/s eta 0:00:01
# Collecting opt-einsum~=3.3.0
#   Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
#      |████████████████████████████████| 65 kB 1.7 MB/s eta 0:00:01
# Requirement already satisfied: numpy~=1.19.2 in ./project_1/lib/python3.6/site-packages (from tensorflow) (1.19.5)
# Collecting tensorboard~=2.5
#   Downloading tensorboard-2.5.0-py3-none-any.whl (6.0 MB)
#      |████████████████████████████████| 6.0 MB 3.3 MB/s eta 0:00:01
# Collecting keras-nightly~=2.5.0.dev
#   Downloading keras_nightly-2.5.0.dev2021032900-py2.py3-none-any.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 3.3 MB/s eta 0:00:01
# Requirement already satisfied: six~=1.15.0 in ./project_1/lib/python3.6/site-packages (from tensorflow) (1.15.0)
# Collecting astunparse~=1.6.3
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting protobuf>=3.9.2
#   Downloading protobuf-3.17.3-cp36-cp36m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 4.2 MB/s eta 0:00:01
# Collecting gast==0.4.0
#   Downloading gast-0.4.0-py3-none-any.whl (9.8 kB)
# Collecting keras-preprocessing~=1.1.2
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
#      |████████████████████████████████| 42 kB 921 kB/s eta 0:00:01
# Requirement already satisfied: typing-extensions~=3.7.4 in ./project_1/lib/python3.6/site-packages (from tensorflow) (3.7.4.3)
# Collecting tensorflow-estimator<2.6.0,>=2.5.0rc0
#   Downloading tensorflow_estimator-2.5.0-py2.py3-none-any.whl (462 kB)
#      |████████████████████████████████| 462 kB 4.6 MB/s eta 0:00:01
# Requirement already satisfied: cached-property in ./project_1/lib/python3.6/site-packages (from h5py~=3.1.0->tensorflow) (1.5.2)
# Collecting werkzeug>=0.11.15
#   Downloading Werkzeug-2.0.1-py3-none-any.whl (288 kB)
#      |████████████████████████████████| 288 kB 1.9 MB/s eta 0:00:01
# Collecting google-auth<2,>=1.6.3
#   Downloading google_auth-1.31.0-py2.py3-none-any.whl (147 kB)
#      |████████████████████████████████| 147 kB 3.4 MB/s eta 0:00:01
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Downloading tensorboard_data_server-0.6.1-py3-none-manylinux2010_x86_64.whl (4.9 MB)
#      |████████████████████████████████| 4.9 MB 744 kB/s eta 0:00:01
# Collecting markdown>=2.6.8
#   Downloading Markdown-3.3.4-py3-none-any.whl (97 kB)
#      |████████████████████████████████| 97 kB 668 kB/s eta 0:00:01
# Collecting requests<3,>=2.21.0
#   Downloading requests-2.25.1-py2.py3-none-any.whl (61 kB)
#      |████████████████████████████████| 61 kB 1.9 MB/s eta 0:00:01
# Collecting tensorboard-plugin-wit>=1.6.0
#   Downloading tensorboard_plugin_wit-1.8.0-py3-none-any.whl (781 kB)
#      |████████████████████████████████| 781 kB 4.5 MB/s eta 0:00:01
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Downloading google_auth_oauthlib-0.4.4-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: setuptools>=41.0.0 in ./project_1/lib/python3.6/site-packages (from tensorboard~=2.5->tensorflow) (53.0.0)
# Collecting cachetools<5.0,>=2.0.0
#   Downloading cachetools-4.2.2-py3-none-any.whl (11 kB)
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.7.2-py3-none-any.whl (34 kB)
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
#      |████████████████████████████████| 155 kB 2.5 MB/s eta 0:00:01
# Collecting requests-oauthlib>=0.7.0
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: importlib-metadata in ./project_1/lib/python3.6/site-packages (from markdown>=2.6.8->tensorboard~=2.5->tensorflow) (3.4.0)
# Collecting pyasn1<0.5.0,>=0.4.6
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
#      |████████████████████████████████| 77 kB 2.9 MB/s eta 0:00:01
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in ./project_1/lib/python3.6/site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow) (1.26.3)
# Collecting chardet<5,>=3.0.2
#   Downloading chardet-4.0.0-py2.py3-none-any.whl (178 kB)
#      |████████████████████████████████| 178 kB 5.3 MB/s eta 0:00:01
# Collecting certifi>=2017.4.17
#   Downloading certifi-2021.5.30-py2.py3-none-any.whl (145 kB)
#      |████████████████████████████████| 145 kB 5.2 MB/s eta 0:00:01
# Collecting idna<3,>=2.5
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
#      |████████████████████████████████| 58 kB 3.7 MB/s eta 0:00:01
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.1.1-py2.py3-none-any.whl (146 kB)
#      |████████████████████████████████| 146 kB 5.7 MB/s eta 0:00:01
# Collecting dataclasses
#   Downloading dataclasses-0.8-py3-none-any.whl (19 kB)
# Requirement already satisfied: zipp>=0.5 in ./project_1/lib/python3.6/site-packages (from importlib-metadata->markdown>=2.6.8->tensorboard~=2.5->tensorflow) (3.4.0)
# Building wheels for collected packages: termcolor, wrapt
#   Building wheel for termcolor (setup.py) ... done
#   Created wheel for termcolor: filename=termcolor-1.1.0-py3-none-any.whl size=4829 sha256=a8272ab8e293b61de74278bd63e9a6d21b8eb1730e2c28318fe95531862283e4
#   Stored in directory: /home/toto/.cache/pip/wheels/93/2a/eb/e58dbcbc963549ee4f065ff80a59f274cc7210b6eab962acdc
#   Building wheel for wrapt (setup.py) ... done
#   Created wheel for wrapt: filename=wrapt-1.12.1-cp36-cp36m-linux_x86_64.whl size=67527 sha256=9189f2d45e0b8c324061c56e03f1586d3043e66fa16d1ace75ebc419bcdb6340
#   Stored in directory: /home/toto/.cache/pip/wheels/32/42/7f/23cae9ff6ef66798d00dc5d659088e57dbba01566f6c60db63
# Successfully built termcolor wrapt
# Installing collected packages: pyasn1, idna, chardet, certifi, rsa, requests, pyasn1-modules, oauthlib, cachetools, requests-oauthlib, google-auth, dataclasses, werkzeug, tensorboard-plugin-wit, tensorboard-data-server, protobuf, markdown, grpcio, google-auth-oauthlib, absl-py, wrapt, termcolor, tensorflow-estimator, tensorboard, opt-einsum, keras-preprocessing, keras-nightly, google-pasta, gast, flatbuffers, astunparse, tensorflow
# Successfully installed absl-py-0.13.0 astunparse-1.6.3 cachetools-4.2.2 certifi-2021.5.30 chardet-4.0.0 dataclasses-0.8 flatbuffers-1.12 gast-0.4.0 google-auth-1.31.0 google-auth-oauthlib-0.4.4 google-pasta-0.2.0 grpcio-1.34.1 idna-2.10 keras-nightly-2.5.0.dev2021032900 keras-preprocessing-1.1.2 markdown-3.3.4 oauthlib-3.1.1 opt-einsum-3.3.0 protobuf-3.17.3 pyasn1-0.4.8 pyasn1-modules-0.2.8 requests-2.25.1 requests-oauthlib-1.3.0 rsa-4.7.2 tensorboard-2.5.0 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.0 tensorflow-2.5.0 tensorflow-estimator-2.5.0 termcolor-1.1.0 werkzeug-2.0.1 wrapt-1.12.1
# WARNING: You are using pip version 21.0.1; however, version 21.1.2 is available.
# You should consider upgrading via the '/home/toto/project_1/project_1/bin/python -m pip install --upgrade pip' command.

# %%
# !pip install keras
# Out:
# Collecting keras
#   Downloading Keras-2.4.3-py2.py3-none-any.whl (36 kB)
# Requirement already satisfied: numpy>=1.9.1 in ./project_1/lib/python3.6/site-packages (from keras) (1.19.5)
# Collecting h5py
#   Downloading h5py-3.1.0-cp36-cp36m-manylinux1_x86_64.whl (4.0 MB)
#      |████████████████████████████████| 4.0 MB 1.5 MB/s eta 0:00:01
# Requirement already satisfied: scipy>=0.14 in ./project_1/lib/python3.6/site-packages (from keras) (1.5.4)
# Collecting pyyaml
#   Downloading PyYAML-5.4.1-cp36-cp36m-manylinux1_x86_64.whl (640 kB)
#      |████████████████████████████████| 640 kB 3.9 MB/s eta 0:00:01
# Collecting cached-property
#   Downloading cached_property-1.5.2-py2.py3-none-any.whl (7.6 kB)
# Installing collected packages: cached-property, pyyaml, h5py, keras
# Successfully installed cached-property-1.5.2 h5py-3.1.0 keras-2.4.3 pyyaml-5.4.1
# WARNING: You are using pip version 21.0.1; however, version 21.1.2 is available.
# You should consider upgrading via the '/home/toto/project_1/project_1/bin/python -m pip install --upgrade pip' command.
